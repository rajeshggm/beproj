# %%
# %pylab inline

import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load your test image here

# %%
img_path = 'Data/val2015/abstract_v002_val2015_000000022100.png'
img_pre = mpimg.imread(img_path)
plt.imshow(img_pre)
plt.show()
# pylab.show()

# %% [markdown]
# # Ask your question here

# %%
ques = 'What is the man sitting on?'

# %% [markdown]
# # Run the following cell to get answers

# %%
run predict.py --image_path 'Data/val2015/abstract_v002_val2015_000000022100.png' --question 'What is the man sitting on?'
# Out:
# 3======> image_embedding.shape: (1, 512, 49)
# 3======> u0.shape: (1, 512)
# 3======> u0.shape: (1, 512, 1)
# 3======> h1.shape: (1, 512, 49)
# 3======> p1.shape: (1, 1, 49)
# 3======> p1.shape: (1, 49, 1)
# 3======> u1.shape: (1, 512, 1)
# 3======> h2.shape: (1, 512, 49)
# 3======> p2.shape: (1, 1, 49)
# 3======> p2.shape: (1, 49, 1)
# 3======> u2.shape: (1, 512, 1)
# 3======> logits.shape: (1, 1000, 1)
# 3======> answer_probab.shape: (1, 1000)
# 3==============> Building Stacked Attention Layer Finished!
# INFO:tensorflow:Restoring parameters from Data/Models/model19.ckpt
# Image: Data/val2015/abstract_v002_val2015_000000022100.png
# Question: What is the man sitting on?
# Ans: couch
# Top Answers
# couch
# chair
# on couch
# by door
# floor

# %% [markdown]
# ### Question:<br>
# What is the man sitting on? <br>
# ### Ans:<br>
# couch <br>
# ### Top Answers:<br>
# couch<br>
# chair<br>
# on couch<br>
# by door<br>
# floor<br>
