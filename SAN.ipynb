# %%
# !git clone https://github.com/rajeshggm/beproj.git
# Out:
# Cloning into 'VQA-SAN'...
# remote: Enumerating objects: 24, done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 24
# Unpacking objects: 100% (24/24), done.

# %%
cd VQA-SAN/Data
# Out:
# /content/VQA-SAN/Data

# %%
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/scene_img/scene_img_abstract_v002_train2015.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Questions_Train_abstract_v002.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Annotations_Train_abstract_v002.zip

# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/scene_img/scene_img_abstract_v002_val2015.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Questions_Val_abstract_v002.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Annotations_Val_abstract_v002.zip
# Out:
# --2020-05-02 15:09:52--  https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/scene_img/scene_img_abstract_v002_train2015.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.146.77
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.146.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2906984514 (2.7G) [application/zip]
# Saving to: ‘scene_img_abstract_v002_train2015.zip’
#
# scene_img_abstract_ 100%[===================>]   2.71G  35.9MB/s    in 78s
#
# 2020-05-02 15:11:10 (35.4 MB/s) - ‘scene_img_abstract_v002_train2015.zip’ saved [2906984514/2906984514]
#
# --2020-05-02 15:11:12--  https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Questions_Train_abstract_v002.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.228.131
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.228.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4608193 (4.4M) [application/zip]
# ...

# %%
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Questions_Train_abstract_v002.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Annotations_Train_abstract_v002.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Questions_Val_abstract_v002.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Annotations_Val_abstract_v002.zip

# %%
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Annotations_Val_abstract_v002.zip

# %%
#real images
# !wget -c  http://images.cocodataset.org/zips/train2014.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/Annotations_Train_mscoco.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/Questions_Train_mscoco.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/Questions_Val_mscoco.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/Annotations_Val_mscoco.zip
# Out:
# --2020-05-01 12:06:05--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.238.171
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.238.171|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  35.0MB/s    in 6m 10s
#
# 2020-05-01 12:12:15 (34.9 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# --2020-05-01 12:12:17--  https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/Annotations_Train_mscoco.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.243.70
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.243.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12167843 (12M) [application/zip]
# Saving to: ‘Annotations_Train_mscoco.zip’
#
# ...

# %%
#real images
# !unzip train2014.zip
# !unzip Questions_Train_mscoco.zip
# !unzip Annotations_Train_mscoco.zip
# !unzip Questions_Val_mscoco.zip
# !unzip Annotations_Val_mscoco.zip

# %%
#testing things
# !wget http://images.cocodataset.org/zips/train2014.zip

# %%
# !unzip train2014.zip

# %%
# !unzip Annotations_Train_abstract_v002.zip
# !unzip Questions_Train_abstract_v002.zip
# Out:
# unzip:  cannot find or open Annotations_Train_abstract_v002.zip, Annotations_Train_abstract_v002.zip.zip or Annotations_Train_abstract_v002.zip.ZIP.
# unzip:  cannot find or open Questions_Train_abstract_v002.zip, Questions_Train_abstract_v002.zip.zip or Questions_Train_abstract_v002.zip.ZIP.

# %%
# !mkdir train2015
# !mkdir val2015

# %%
# !unzip Annotations_Train_abstract_v002.zip
# !unzip Annotations_Val_abstract_v002.zip
# !unzip Questions_Train_abstract_v002.zip
# !unzip Questions_Val_abstract_v002.zip
# !unzip scene_img_abstract_v002_train2015.zip -d train2015
# !unzip scene_img_abstract_v002_val2015.zip -d val2015
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: val2015/abstract_v002_val2015_000000025001.png
#   inflating: val2015/abstract_v002_val2015_000000025002.png
#   inflating: val2015/abstract_v002_val2015_000000025003.png
#   inflating: val2015/abstract_v002_val2015_000000025004.png
#   inflating: val2015/abstract_v002_val2015_000000025005.png
#   inflating: val2015/abstract_v002_val2015_000000025006.png
#   inflating: val2015/abstract_v002_val2015_000000025007.png
#   inflating: val2015/abstract_v002_val2015_000000025008.png
#   inflating: val2015/abstract_v002_val2015_000000025009.png
#   inflating: val2015/abstract_v002_val2015_000000025010.png
#   inflating: val2015/abstract_v002_val2015_000000025011.png
#   inflating: val2015/abstract_v002_val2015_000000025012.png
#   inflating: val2015/abstract_v002_val2015_000000025013.png
#   inflating: val2015/abstract_v002_val2015_000000025014.png
#   inflating: val2015/abstract_v002_val2015_000000025015.png
# ...

# %%
cd Models
# Out:
# /content/VQA-SAN/Data/Models

# %%
# !unzip Model19.zip
# Out:
# Archive:  Model19.zip
#   inflating: checkpoint
#   inflating: model19.ckpt.data-00000-of-00001
#   inflating: model19.ckpt.index
#   inflating: model19.ckpt.meta

# %%
cd Data
# Out:
# /content/VQA-SAN/Data

# %%
# !wget -c https://gist.githubusercontent.com/ksimonyan/3785162f95cd2d5fee77/raw/bb2b4fe0a9bb0669211cf3d0bc949dfdda173e9e/VGG_ILSVRC_19_layers_deploy.prototxt
# !wget -c http://www.robots.ox.ac.uk/~vgg/software/very_deep/caffe/VGG_ILSVRC_19_layers.caffemodel
# Out:
# --2020-05-02 15:16:40--  https://gist.githubusercontent.com/ksimonyan/3785162f95cd2d5fee77/raw/bb2b4fe0a9bb0669211cf3d0bc949dfdda173e9e/VGG_ILSVRC_19_layers_deploy.prototxt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5499 (5.4K) [text/plain]
# Saving to: ‘VGG_ILSVRC_19_layers_deploy.prototxt’
#
# VGG_ILSVRC_19_layer 100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2020-05-02 15:16:40 (61.2 MB/s) - ‘VGG_ILSVRC_19_layers_deploy.prototxt’ saved [5499/5499]
#
# --2020-05-02 15:16:51--  http://www.robots.ox.ac.uk/~vgg/software/very_deep/caffe/VGG_ILSVRC_19_layers.caffemodel
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# ...

# %%
cd ..
# Out:
# /content/VQA-SAN

# %%
# !python extract_cnn7.py --split=val
# Out:
# WARNING:tensorflow:From extract_cnn7.py:32: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From extract_cnn7.py:35: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From extract_cnn7.py:38: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# [VGG16] Name Placeholder [<tf.Tensor 'Placeholder:0' shape=(?, 224, 224, 3) dtype=float32>]
# [VGG16] Name import/images [<tf.Tensor 'import/images:0' shape=<unknown> dtype=float32>]
# [VGG16] Name import/mul/y [<tf.Tensor 'import/mul/y:0' shape=() dtype=float32>]
# [VGG16] Name import/mul [<tf.Tensor 'import/mul:0' shape=(?, 224, 224, 3) dtype=float32>]
# [VGG16] Name import/split/split_dim [<tf.Tensor 'import/split/split_dim:0' shape=() dtype=int32>]
# ...

# %%
# !wget http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# Out:
# --2020-05-01 12:26:55--  http://download.tensorflow.org/models/vgg_16_2016_08_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.143.128, 2a00:1450:4013:c01::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.143.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 513324920 (490M) [application/x-tar]
# Saving to: ‘vgg_16_2016_08_28.tar.gz’
#
# vgg_16_2016_08_28.t 100%[===================>] 489.54M  42.5MB/s    in 12s
#
# 2020-05-01 12:27:08 (40.5 MB/s) - ‘vgg_16_2016_08_28.tar.gz’ saved [513324920/513324920]

# %%
# !tar xf vgg_16_2016_08_28.tar.gz

# %%
# !python predict.py --image_path="/content/VQA-SAN/download.png" --question="What is the man sitting on?"

# %%
cd content/VQA-SAN/
# Out:
# /content/VQA-SAN

# %%
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/scene_img/scene_img_abstract_v002_test2015.zip
# !wget -c https://s3.amazonaws.com/cvmlp/vqa/abstract_v002/vqa/Questions_Test_abstract_v002.zip

# %%
# !unzip Questions_Test_abstract_v002.zip
# Out:
# Archive:  Questions_Test_abstract_v002.zip
#   inflating: OpenEnded_abstract_v002_test2015_questions.json
#   inflating: MultipleChoice_abstract_v002_test2015_questions.json

# %%
# %tensorflow_version 1.14
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
# !python extract_cnn7.py --split=train
# Out:
# Streaming output truncated to the last 5000 lines.
# Images Processed 3350
# Time for batch 10 photos 0.2025769999999909
# Hours For Whole Dataset 0.11254277777777273
# Images Processed 3360
# Time for batch 10 photos 0.19066999999999723
# Hours For Whole Dataset 0.10592777777777625
# Images Processed 3370
# Time for batch 10 photos 0.19194500000000403
# Hours For Whole Dataset 0.10663611111111335
# Images Processed 3380
# Time for batch 10 photos 0.19324500000000455
# Hours For Whole Dataset 0.10735833333333586
# Images Processed 3390
# Time for batch 10 photos 0.18337699999999302
# Hours For Whole Dataset 0.10187611111110724
# Images Processed 3400
# Time for batch 10 photos 0.19465600000000904
# Hours For Whole Dataset 0.10814222222222725
# Images Processed 3410
# Time for batch 10 photos 0.18940800000000024
# Hours For Whole Dataset 0.1052266666666668
# Images Processed 3420
# Time for batch 10 photos 0.19422499999998877
# Hours For Whole Dataset 0.10790277777777153
# ...

# %%
pip install scipy==1.1.0
# Out:
# ...
#      |████████████████████████████████| 31.2MB 106kB/s
# ...
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
# !ls Data/train2014

# %%
# !python data_loader.py
# Out:
# Loading Training questions
# Loading Training anwers
# Loading Val questions
# Loading Val answers
# Ans 60000 30000
# Qu 60000 30000
# Max Question Length 21
# Training Data 58332
# Validation Data 29258
# Saving qa_data
# Saving vocab_data

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Training Accuracy 0.885
# Time for one batch 0.09296200000005683
# Hours For one epoch 0.007514428333337928
# Loss 64.29549 207 31
# Training Accuracy 0.89
# Time for one batch 0.09586500000000342
# Hours For one epoch 0.007749087500000276
# Loss 73.40271 208 31
# Training Accuracy 0.885
# Time for one batch 0.08911699999998746
# Hours For one epoch 0.007203624166665653
# Loss 72.970406 209 31
# Training Accuracy 0.87
# Time for one batch 0.09637400000008256
# Hours For one epoch 0.00779023166667334
# Loss 59.857708 210 31
# Training Accuracy 0.895
# Time for one batch 0.09172100000000682
# Hours For one epoch 0.0074141141666672185
# Loss 59.71783 211 31
# Training Accuracy 0.915
# Time for one batch 0.10085500000002412
# Hours For one epoch 0.008152445833335282
# Loss 74.5583 212 31
# Training Accuracy 0.88
# Time for one batch 0.09293899999988753
# Hours For one epoch 0.007512569166657575
# Loss 83.68397 213 31
# ...

# %%
# !python predict.py
# Out:
# WARNING:tensorflow:From /content/VQA-SAN/utils.py:47: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# WARNING:tensorflow:From /content/VQA-SAN/utils.py:49: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/VQA-SAN/utils.py:51: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /content/VQA-SAN/utils.py:53: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-05-02 16:06:32.771481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-02 16:06:32.789524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
# !zip model23.zip model34.ckpt.data-00000-of-00001 model34.ckpt.index model34.ckpt.meta
# Out:
#   adding: model34.ckpt.data-00000-of-00001 (deflated 10%)
#   adding: model34.ckpt.index (deflated 56%)
#   adding: model34.ckpt.meta (deflated 91%)

# %%
cd Data/Models
# Out:
# /content/VQA-SAN/Data/Models

# %%
cd ..
# Out:
# /content/VQA-SAN

# %%
# !python evaluate.py
# Out:
# Reading QA DATA
# Reading cnn7 features
# tcmalloc: large alloc 2007040000 bytes == 0x7b0e000 @  0x7fcf4d76b1e7 0x7fcf4abea5e1 0x7fcf4ac4d138 0x7fcf4ac4d3f7 0x7fcf4ace53e8 0x50ac25 0x50d390 0x508245 0x5894fd 0x7fcf0d696e5c 0x59509c 0x5a522c 0x4a827f 0x7fcf4ac4c4ac 0x7fcf4ac5044f 0x7fcf4ac50855 0x7fcf4ace7b1d 0x50ac25 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f
# tcmalloc: large alloc 2007040000 bytes == 0x7f51e000 @  0x7fcf4d76b1e7 0x7fcf4abea5e1 0x7fcf4ac4f8e0 0x7fcf4ac4fb42 0x7fcf4ac4fffe 0x7fcf4ac50855 0x7fcf4ace7b1d 0x50ac25 0x50c5b9 0x509d48 0x50aa7d 0x50c5b9 0x508245 0x50a080 0x50aa7d 0x50c5b9 0x508245 0x50b403 0x635222 0x6352d7 0x638a8f 0x639631 0x4b0f40 0x7fcf4d368b97 0x5b2fda
# CNN7 features (10000, 512, 49)
# image_id_list (10000,)
# WARNING:tensorflow:From /content/VQA-SAN/vis_lstm_model.py:17: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# ...
